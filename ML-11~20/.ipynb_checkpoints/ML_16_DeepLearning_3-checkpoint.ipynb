# %%
# tensorflow2-回归：经典的Auto MPG数据集
import tensorflow as tf
import numpy as np
import pandas as pd
# 1. 数据集获取
dataset_path = tf.keras.utils.get_file('auto-mpg.data',
                                   'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data')

# %%
dataset_path
# Out:
# 'C:\\Users\\CUP\\.keras\\datasets\\auto-mpg.data'

# %%
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin'] 
raw_dataset = pd.read_csv(dataset_path, names=column_names,
                         na_values='?', comment='\t',
                         sep=' ', skipinitialspace=True)

dataset = raw_dataset.copy()
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1

# %%
# 2. 数据处理
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
dataset = dataset.dropna()

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
origin = dataset.pop('Origin')
dataset['USA'] = (origin == 1)*1.0
dataset['Europe'] = (origin == 2)*1.0
dataset['Japan'] = (origin == 3)*1.0
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  USA  Europe  Japan
# 393          82  1.0     0.0    0.0
# 394          82  0.0     1.0    0.0
# 395          82  1.0     0.0    0.0
# 396          82  1.0     0.0    0.0
# 397          82  1.0     0.0    0.0

# %%
# 3. 划分数据集
train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
train_dataset.shape,test_dataset.shape
# Out:
# ((314, 10), (78, 10))

# %%
# 4. 数据可视化与统计
import seaborn as sns
sns.pairplot(train_dataset[["MPG", "Cylinders", "Displacement", "Weight"]], diag_kind="kde")

# %%
train_stats = train_dataset.describe()
train_stats
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.310510    5.477707    195.318471  104.869427  2990.251592
# std      7.728652    1.699788    104.331589   38.096214   843.898596
# min     10.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.000000    4.000000    105.500000   76.250000  2256.500000
# 50%     22.000000    4.000000    151.000000   94.500000  2822.500000
# 75%     28.950000    8.000000    265.750000  128.000000  3608.000000
# max     46.600000    8.000000    455.000000  225.000000  5140.000000
#
#        Acceleration  Model Year         USA      Europe       Japan
# count    314.000000  314.000000  314.000000  314.000000  314.000000
# mean      15.559236   75.898089    0.624204    0.178344    0.197452
# std        2.789230    3.675642    0.485101    0.383413    0.398712
# min        8.000000   70.000000    0.000000    0.000000    0.000000
# 25%       13.800000   73.000000    0.000000    0.000000    0.000000
# 50%       15.500000   76.000000    1.000000    0.000000    0.000000
# 75%       17.200000   79.000000    1.000000    0.000000    0.000000
# max       24.800000   82.000000    1.000000    1.000000    1.000000

# %%
train_stats.pop("MPG")
# Out:
# count    314.000000
# mean      23.310510
# std        7.728652
# min       10.000000
# 25%       17.000000
# 50%       22.000000
# 75%       28.950000
# max       46.600000
# Name: MPG, dtype: float64

# %%
train_stats
# Out:
#         Cylinders  Displacement  Horsepower       Weight  Acceleration  \
# count  314.000000    314.000000  314.000000   314.000000    314.000000
# mean     5.477707    195.318471  104.869427  2990.251592     15.559236
# std      1.699788    104.331589   38.096214   843.898596      2.789230
# min      3.000000     68.000000   46.000000  1649.000000      8.000000
# 25%      4.000000    105.500000   76.250000  2256.500000     13.800000
# 50%      4.000000    151.000000   94.500000  2822.500000     15.500000
# 75%      8.000000    265.750000  128.000000  3608.000000     17.200000
# max      8.000000    455.000000  225.000000  5140.000000     24.800000
#
#        Model Year         USA      Europe       Japan
# count  314.000000  314.000000  314.000000  314.000000
# mean    75.898089    0.624204    0.178344    0.197452
# std      3.675642    0.485101    0.383413    0.398712
# min     70.000000    0.000000    0.000000    0.000000
# 25%     73.000000    0.000000    0.000000    0.000000
# 50%     76.000000    1.000000    0.000000    0.000000
# 75%     79.000000    1.000000    0.000000    0.000000
# max     82.000000    1.000000    1.000000    1.000000

# %%
train_stats = train_stats.transpose()

# %%
train_stats
# Out:
#               count         mean         std     min      25%     50%  \
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# USA           314.0     0.624204    0.485101     0.0     0.00     1.0
# Europe        314.0     0.178344    0.383413     0.0     0.00     0.0
# Japan         314.0     0.197452    0.398712     0.0     0.00     0.0
#
#                   75%     max
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# USA              1.00     1.0
# Europe           0.00     1.0
# Japan            0.00     1.0

# %%
# 5. 取出标签
train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')

# %%
train_dataset
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year  \
# 146          4          90.0        75.0  2125.0          14.5          74
# 282          4         140.0        88.0  2890.0          17.3          79
# 69           8         350.0       160.0  4456.0          13.5          72
# 378          4         105.0        63.0  2125.0          14.7          82
# 331          4          97.0        67.0  2145.0          18.0          80
# ..         ...           ...         ...     ...           ...         ...
# 281          6         200.0        85.0  2990.0          18.2          79
# 229          8         400.0       180.0  4220.0          11.1          77
# 150          4         108.0        93.0  2391.0          15.5          74
# 145          4          83.0        61.0  2003.0          19.0          74
# 182          4         107.0        86.0  2464.0          15.5          76
#
#      USA  Europe  Japan
# 146  1.0     0.0    0.0
# 282  1.0     0.0    0.0
# 69   1.0     0.0    0.0
# 378  1.0     0.0    0.0
# 331  0.0     0.0    1.0
# ..   ...     ...    ...
# 281  1.0     0.0    0.0
# 229  1.0     0.0    0.0
# 150  0.0     0.0    1.0
# 145  0.0     0.0    1.0
# 182  0.0     1.0    0.0
#
# [314 rows x 9 columns]

# %%
test_dataset
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year  \
# 9            8         390.0       190.0  3850.0           8.5          70
# 25           8         360.0       215.0  4615.0          14.0          70
# 28           8         304.0       193.0  4732.0          18.5          70
# 31           4         113.0        95.0  2228.0          14.0          71
# 33           6         232.0       100.0  2634.0          13.0          71
# ..         ...           ...         ...     ...           ...         ...
# 369          4         112.0        88.0  2395.0          18.0          82
# 375          4         105.0        74.0  1980.0          15.3          82
# 382          4         108.0        70.0  2245.0          16.9          82
# 384          4          91.0        67.0  1965.0          15.7          82
# 396          4         120.0        79.0  2625.0          18.6          82
#
#      USA  Europe  Japan
# 9    1.0     0.0    0.0
# 25   1.0     0.0    0.0
# 28   1.0     0.0    0.0
# 31   0.0     0.0    1.0
# 33   1.0     0.0    0.0
# ..   ...     ...    ...
# 369  1.0     0.0    0.0
# 375  0.0     1.0    0.0
# 382  0.0     0.0    1.0
# 384  0.0     0.0    1.0
# 396  1.0     0.0    0.0
#
# [78 rows x 9 columns]

# %%
# 6. 标准化数据
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']

normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

# %%
# 7. 模型构建
from tensorflow.keras import layers
def build_model():
    model = tf.keras.Sequential([
        layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
        layers.Dense(64, activation='relu'),
        layers.Dense(1)
    ])

    optimizer = tf.keras.optimizers.RMSprop(0.001)
    model.compile(loss='mse',
                 optimizer=optimizer,
                 metrics=['mae', 'mse'])
    return model

model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                640
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = normed_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# 1/1 [==============================] - 0s 127ms/step
# array([[-0.02590416],
#        [ 0.23255204],
#        [ 0.15075958],
#        [ 0.3267812 ],
#        [ 0.30282143],
#        [ 0.16497259],
#        [ 0.33773506],
#        [ 0.52752346],
#        [ 0.02972379],
#        [ 0.01679118]], dtype=float32)

# %%
# 8. 训练
class PrintDot(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='>')

EPOCHS = 1000
history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.head()
# Out:
#          loss        mae         mse    val_loss    val_mae     val_mse  epoch
# 0  559.412354  22.379128  559.412354  546.397583  22.051229  546.397583      0
# 1  506.442169  21.179165  506.442169  491.985321  20.782963  491.985321      1
# 2  455.689270  19.950214  455.689270  435.072723  19.355930  435.072723      2
# 3  400.690918  18.526863  400.690918  372.765808  17.691462  372.765808      3
# 4  340.609955  16.903412  340.609955  307.203613  15.803474  307.203613      4

# %%
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 995  2.287733  0.943133  2.287733  9.011747  2.389230  9.011747    995
# 996  2.525191  1.017906  2.525191  8.517931  2.275750  8.517931    996
# 997  2.312558  0.950405  2.312558  8.854384  2.322018  8.854384    997
# 998  2.433592  1.016666  2.433592  9.156583  2.365786  9.156583    998
# 999  2.253211  0.941061  2.253211  8.644281  2.274880  8.644281    999

# %%
import matplotlib.pyplot as plt
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error [MPG]')
    plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
    plt.ylim([0,5])
    plt.legend()

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error [$MPG^2$]')
    plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
    plt.ylim([0,20])
    plt.legend()
    plt.show()


plot_history(history)

# %%
# 9. 优化
model = build_model()


early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(normed_train_data, train_labels, epochs=EPOCHS,
                    validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# .>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>.>

# %%
loss, mae, mse = model.evaluate(normed_test_data, test_labels, verbose=0)

print("Testing set Mean Abs Error: {:5.2f} MPG".format(mae))
# Out:
# Testing set Mean Abs Error:  1.81 MPG

# %%
# 10. 预测
test_predictions = model.predict(normed_test_data).flatten()
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
# 11. 误差
error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error [MPG]")
_ = plt.ylabel("Count")
