# %%
# !pip install chemspipy
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for chemspipy: filename=ChemSpiPy-2.0.0-py3-none-any.whl size=15080 sha256=499ad0bdaa54b93728b6064f07162eeb7e7a7185118176df1ee5ed29c1a73d93
#   Stored in directory: /home/cup/.cache/pip/wheels/58/ee/7c/9ab88f910dc50328446834b6a93435b52217118375d961d286
# Successfully built chemspipy
# ...

# %%
from chemspipy import ChemSpider
import os
api_key = os.environ["CHEMSPIDER_API_KEY"]
cs = ChemSpider(api_key)

# %%
cs
# Out:
# ChemSpider()

# %%
from rdkit import Chem
from rdkit.Chem import Draw
def display_mols(mol_name):
    mols=[]
    for result in cs.search(mol_name):
        print(result.common_name,"\t",result.smiles,"\t",result.molecular_formula)
        mol=Chem.MolFromSmiles(result.smiles)
        mols.append(mol)
    
    img=Draw.MolsToGridImage(mols,molsPerRow=4,subImgSize=(200,200),legends=['' for x in mols])
    return img

# %%
display_mols('Glucose')
# Out:
# D-Glucopyranose 	 C([C@@H]1[C@H]([C@@H]([C@H](C(O1)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# .beta.-D-Glucopyranose 	 C([C@@H]1[C@H]([C@@H]([C@H]([C@@H](O1)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# .alpha.-D-Glucopyranose 	 C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# D-(+)-Glucose 	 C([C@H]([C@H]([C@@H]([C@H](C=O)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# L-glucopyranose 	 C([C@H]1[C@@H]([C@H]([C@@H](C(O1)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# alpha-L-Glucopyranose 	 C([C@H]1[C@@H]([C@H]([C@@H]([C@@H](O1)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# beta-L-Glucopyranose 	 C([C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# L-(&minus;)-Glucose 	 C([C@@H]([C@@H]([C@H]([C@@H](C=O)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# D-Glucofuranose 	 O[C@H]1[C@H](OC(O)[C@@H]1O)[C@H](O)CO 	 C_{6}H_{12}O_{6}
# alpha-D-Glucofuranose 	 C([C@H]([C@@H]1[C@@H]([C@H]([C@H](O1)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# beta-D-Glucofuranose 	 C([C@H]([C@@H]1[C@@H]([C@H]([C@@H](O1)O)O)O)O)O 	 C_{6}H_{12}O_{6}
# ...

# %%
display_mols('pvp')
# Out:
# 2-{4-[5-chloro-6-methyl-2-(2-pyridyl)pyrimidin-4-yl]piperazino}ethan-1-ol 	 Cc1c(c(nc(n1)c2ccccn2)N3CCN(CC3)CCO)Cl 	 C_{16}H_{20}ClN_{5}O
# alpha-Pyrrolidinopentiophenone 	 CCCC(C(=O)C1=CC=CC=C1)N2CCCC2 	 C_{15}H_{21}NO
# 4-Biphenylboronic acid pinacol ester 	 B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)c3ccccc3 	 C_{18}H_{21}BO_{2}

# %%
display_mols('PVP')
# Out:
# 2-{4-[5-chloro-6-methyl-2-(2-pyridyl)pyrimidin-4-yl]piperazino}ethan-1-ol 	 Cc1c(c(nc(n1)c2ccccn2)N3CCN(CC3)CCO)Cl 	 C_{16}H_{20}ClN_{5}O
# alpha-Pyrrolidinopentiophenone 	 CCCC(C(=O)C1=CC=CC=C1)N2CCCC2 	 C_{15}H_{21}NO
# 4-Biphenylboronic acid pinacol ester 	 B1(OC(C(O1)(C)C)(C)C)c2ccc(cc2)c3ccccc3 	 C_{18}H_{21}BO_{2}

# %%
display_mols('inhibitor')
# Out:
# PKCbeta inhibitor 	 c1ccc(cc1)NC2=C(C(=O)NC2=O)c3cn(c4c3cccc4)CCCn5ccnc5 	 C_{24}H_{21}N_{5}O_{2}

# %%
display_mols('hydrate')
# Out:
# Hydrazine hydrate 	 NN.O 	 H_{6}N_{2}O
# hydrate 	 c1ccc2c(c1)nnn2O.O 	 C_{6}H_{7}N_{3}O_{2}
# hydrate 	 Cc1cccc(c1)S(=O)(=O)O.O 	 C_{7}H_{10}O_{4}S

# %%
display_mols('polyvinylpyrrolidone')
# Out:
# 2,5,6-Trimethyl-2-cyclohexen-1-one 	 CC1CC=C(C(=O)C1C)C 	 C_{9}H_{14}O

# %%
display_mols('NaCl')
# Out:
# Sodium chloride 	 [Na+].[Cl-] 	 ClNa

# %%
display_mols('SDS')
# Out:
# Sodium Lauryl Sulfate 	 CCCCCCCCCCCCOS(=O)(=O)[O-].[Na+] 	 C_{12}H_{25}NaO_{4}S

# %%
display_mols('SDBS')
# Out:
# Sodium 4-dodecylbenzenesulfonate 	 CCCCCCCCCCCCc1ccc(cc1)S(=O)(=O)[O-].[Na+] 	 C_{18}H_{29}NaO_{3}S

# %%
display_mols('Chlorite')
# Out:
# Chlorite 	 [O-]Cl=O 	 ClO_{2}

# %%
display_mols('Kaolinite')
# Out:
# Mullite 	 O=[Al]O[Al]=O.O=[Si]=O 	 Al_{2}O_{5}Si

# %%
display_mols('ADP')
# Out:
# Adenosine diphosphate 	 c1nc(c2c(n1)n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3)COP(=O)(O)OP(=O)(O)O)O)O)N 	 C_{10}H_{15}N_{5}O_{10}P_{2}
# ADP 	 c1nc(c2c(n1)n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3)COP(=O)(O)OP(=O)(O)[O-])O)O)N.[K+] 	 C_{10}H_{14}KN_{5}O_{10}P_{2}
# ADP 	 c1nc(c2c(n1)n(cn2)[C@H]3[C@@H]([C@@H]([C@H](O3)COP(=O)(O)OP(=O)([O-])[O-])O)O)N.C1CCC(CC1)[NH3+].C1CCC(CC1)[NH3+] 	 C_{22}H_{41}N_{7}O_{10}P_{2}

# %%
display_mols('DMC')
# Out:
# Dimethyl carbonate 	 COC(=O)OC 	 C_{3}H_{6}O_{3}
# DMC 	 CN1CC[N+](=C1Cl)C.[Cl-] 	 C_{5}H_{10}Cl_{2}N_{2}

# %%
display_mols('Vinylpyrrolidone')
# Out:
# 1-Vinyl-2-pyrrolidone 	 C=CN1CCCC1=O 	 C_{6}H_{9}NO

# %%
display_mols('Methyl acrylate')
# Out:
# AT2800000 	 COC(=O)C=C 	 C_{4}H_{6}O_{2}

# %%
display_mols('Ethyl acrylate')
# Out:
# AT0700000 	 CCOC(=O)C=C 	 C_{5}H_{8}O_{2}

# %%
display_mols('Propyl acrylate')
# Out:
# Propyl acrylate 	 CCCOC(=O)C=C 	 C_{6}H_{10}O_{2}

# %%
display_mols('Butyl acrylate')
# Out:
# butyl acrylate 	 CCCCOC(=O)C=C 	 C_{7}H_{12}O_{2}
# tert-Butyl acrylate 	 CC(C)(C)OC(=O)C=C 	 C_{7}H_{12}O_{2}

# %%
display_mols('n-hexene')
# Out:
# hexene 	 CCCCC=C 	 C_{6}H_{12}

# %%
display_mols('Guar gum')
# Out:
# 17-Allyl-1,14-dihydroxy-12-[2-(4-hydroxy-3-methoxycyclohexyl)-1-methylvinyl]-23,25-dimethoxy-13,19,21,27-tetramethyl-11,28-dioxa-4-azatricyclo[22.3.1.04,9]octacos-18-ene-2,3,10,16-tetraone 	 C[C@@H]1C[C@@H]([C@@H]2[C@H](C[C@H]([C@@](O2)(C(=O)C(=O)N3CCCC[C@H]3C(=O)O[C@@H]([C@@H]([C@H](CC(=O)[C@@H](/C=C(\C1)/C)CC=C)O)C)/C(=C/[C@@H]4CC[C@H]([C@@H](C4)OC)O)/C)O)C)OC)OC 	 C_{44}H_{69}NO_{12}
# disodium [[[5-(6-aminopurin-9-yl)-3-hydroxy-tetrahydrofuran-2-yl]methoxy-oxido-phosphoryl]oxy-hydroxy-phosphoryl] hydrogen phosphate 	 c1nc(c2c(n1)n(cn2)C3CC(C(O3)COP(=O)([O-])OP(=O)(O)OP(=O)(O)[O-])O)N.[Na+].[Na+] 	 C_{10}H_{14}N_{5}Na_{2}O_{12}P_{3}
# disodium;[[[5-(6-aminopurin-9-yl)-3-hydroxy-tetrahydrofuran-2-yl]oxy-methoxy-phosphoryl]oxy-hydroxy-phosphoryl] phosphate 	 [Na+].[Na+].COP(=O)(OP(O)(=O)OP([O-])([O-])=O)OC1OC(CC1O)N1C=NC2=C(N)N=CN=C12 	 C_{10}H_{14}N_{5}Na_{2}O_{12}P_{3}

# %%
display_mols('Boron nitride')
# Out:
# Boron nitride 	 B#N 	 BN

# %%
display_mols('lecithin')
# Out:
# LECITHIN 	 CCCCCCCCCCCCCCCC(=O)OC[C@H](COP(=O)([O-])OCC[N+](C)(C)C)OC(=O)CCCCCCC/C=C\C/C=C\CCCCC 	 C_{42}H_{80}NO_{8}P

# %%
display_mols('MEG')
# Out:
# 2-Guanidinoethanethiol 	 C(CS)N=C(N)N 	 C_{3}H_{9}N_{3}S
# (E)-Amino[(2-sulfanylethyl)imino]methanaminium bromide 	 C(CS)/N=C(/[NH3+])\N.[Br-] 	 C_{3}H_{10}BrN_{3}S
# Sodium 4-[(2-carbamimidamidoethyl)sulfanyl]-4-oxobutanoate 	 C(CC(=O)SCCNC(=N)N)C(=O)[O-].[Na+] 	 C_{7}H_{12}N_{3}NaO_{3}S

# %%
display_mols('Glycine')
# Out:
# Glycine 	 C(C(=O)O)N 	 C_{2}H_{5}NO_{2}

# %%
display_mols('Alanine')
# Out:
# DL-Alanine 	 CC(C(=O)O)N 	 C_{3}H_{7}NO_{2}
# L-(+)-Alanine 	 C[C@@H](C(=O)O)N 	 C_{3}H_{7}NO_{2}
# D-(-)-Alanine 	 C[C@H](C(=O)O)N 	 C_{3}H_{7}NO_{2}

# %%
display_mols('Valine')
# Out:
# DL-Valine 	 CC(C)C(C(=O)O)N 	 C_{5}H_{11}NO_{2}
# L-(+)-Valine 	 CC(C)[C@@H](C(=O)O)N 	 C_{5}H_{11}NO_{2}

# %%
display_mols('Serine')
# Out:
# DL-Serine 	 C(C(C(=O)O)N)O 	 C_{3}H_{7}NO_{3}
# L-(-)-Serine 	 C([C@@H](C(=O)O)N)O 	 C_{3}H_{7}NO_{3}
# D-(-)-serine 	 C([C@H](C(=O)O)N)O 	 C_{3}H_{7}NO_{3}

# %%
display_mols('glutamic')
# Out:
# [18:09:40]
#
# ****
# Pre-condition Violation
# no draw context
# Violation occurred on line 214 in file /project/build/temp.linux-x86_64-cpython-311/rdkit/Code/GraphMol/MolDraw2D/MolDraw2DCairo.cpp
# Failed Expression: dp_cr
# ****
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 display_mols('glutamic')
#
# Cell In[19], line 10, in display_mols(mol_name)
#       7     mol=Chem.MolFromSmiles(result.smiles)
#       8     mols.append(mol)
# ---> 10 img=Draw.MolsToGridImage(mols,molsPerRow=4,subImgSize=(200,200),legends=['' for x in mols])
#      11 return img
#
# File ~/softwares/miniconda/miniconda3/envs/py3.11/lib/python3.11/site-packages/rdkit/Chem/Draw/IPythonConsole.py:268, in ShowMols(mols, maxMols, **kwargs)
#     265 if "drawOptions" not in kwargs:
#     266   kwargs["drawOptions"] = drawOptions
# --> 268 res = fn(mols, **kwargs)
# ...
