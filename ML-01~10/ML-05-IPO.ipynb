# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# IPOFILE = "ipo-data.xlsx"
IPOFILE = "SCOOP-Rating-Performance.xls"
ipo = pd.read_excel(IPOFILE,skiprows=35,nrows=206)
ipo
# Out:
#           Date                          Issuer  Symbol  \
# 0          NaT                            2020     NaN
# 1   2020-01-17                          I-Mab     IMAB
# 2   2020-01-17                          LIZHI     LIZI
# 3   2020-01-17     Phoenix Tree Holdings Ltd.      DNK
# 4   2020-01-17             Velocity Financial      VEL
# ..         ...                             ...     ...
# 201 2020-09-10    Starboard Value Acquisition    SVACU
# 202 2020-09-11         Broadstone Acquisition    BSN.U
# 203 2020-09-11                    Ribbit LEAP   LEAP.U
# 204 2020-09-11  Tortoise Acquisition Corp. II   SNPR.U
# 205 2020-09-11           TWC Tech Holdings II    TWCTU
#
#                                               Managers  Price  Price.1  \
# 0                                                  NaN    NaN      NaN
# 1                                      Jefferies/ CICC   14.0    14.75
# 2                             Credit Suisse/ Citigroup   11.0    11.03
# ...

# %%
ipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        205 non-null    datetime64[ns]
#  1   Issuer      206 non-null    object
#  2   Symbol      205 non-null    object
#  3    Managers   205 non-null    object
#  4   Price       205 non-null    float64
#  5   Price.1     205 non-null    float64
#  6   Close       205 non-null    float64
#  7   % Px Chng   205 non-null    float64
#  8   Opening     205 non-null    float64
#  9   Close.1     205 non-null    float64
#  10  Ratings     205 non-null    object
#  11  Performed   18 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(5)
# memory usage: 19.4+ KB

# %%
ipo.describe()
# Out:
#             Price     Price.1       Close  % Px Chng      Opening     Close.1
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean    13.747463   17.558341   17.726161    0.205957    3.810878    3.978698
# std      5.310154   11.658875   12.836371    0.417217    7.491345    8.926462
# min      4.000000    4.340000    3.860000   -0.228000   -4.150000   -4.610000
# 25%     10.000000   10.020000   10.030000    0.000000    0.000000    0.000000
# 50%     10.000000   10.620000   10.790000    0.020000    0.310000    0.200000
# 75%     18.000000   22.260000   21.700000    0.261667    4.450000    4.150000
# max     31.000000   71.000000   91.590000    2.493750   44.000000   60.590000

# %%
ipo = ipo.drop(ipo.index[0])
ipo
# Out:
#           Date                          Issuer  Symbol  \
# 1   2020-01-17                          I-Mab     IMAB
# 2   2020-01-17                          LIZHI     LIZI
# 3   2020-01-17     Phoenix Tree Holdings Ltd.      DNK
# 4   2020-01-17             Velocity Financial      VEL
# 5   2020-01-24              Gores Holdings IV    GHIVU
# ..         ...                             ...     ...
# 201 2020-09-10    Starboard Value Acquisition    SVACU
# 202 2020-09-11         Broadstone Acquisition    BSN.U
# 203 2020-09-11                    Ribbit LEAP   LEAP.U
# 204 2020-09-11  Tortoise Acquisition Corp. II   SNPR.U
# 205 2020-09-11           TWC Tech Holdings II    TWCTU
#
#                                               Managers  Price  Price.1  \
# 1                                      Jefferies/ CICC   14.0    14.75
# 2                             Credit Suisse/ Citigroup   11.0    11.03
# 3                Citigroup/ Credit Suisse/ J.P. Morgan   13.5    13.50
# ...

# %%
ipo.columns
# Out:
# Index(['Date', 'Issuer', 'Symbol', ' Managers', 'Price', 'Price.1', 'Close',
#        '% Px Chng ', 'Opening', 'Close.1', 'Ratings', 'Performed'],
#       dtype='object')

# %%
ipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 1 to 205
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        205 non-null    datetime64[ns]
#  1   Issuer      205 non-null    object
#  2   Symbol      205 non-null    object
#  3    Managers   205 non-null    object
#  4   Price       205 non-null    float64
#  5   Price.1     205 non-null    float64
#  6   Close       205 non-null    float64
#  7   % Px Chng   205 non-null    float64
#  8   Opening     205 non-null    float64
#  9   Close.1     205 non-null    float64
#  10  Ratings     205 non-null    object
#  11  Performed   18 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(5)
# memory usage: 19.3+ KB

# %%
ipo
# Out:
#           Date                          Issuer  Symbol  \
# 1   2020-01-17                          I-Mab     IMAB
# 2   2020-01-17                          LIZHI     LIZI
# 3   2020-01-17     Phoenix Tree Holdings Ltd.      DNK
# 4   2020-01-17             Velocity Financial      VEL
# 5   2020-01-24              Gores Holdings IV    GHIVU
# ..         ...                             ...     ...
# 201 2020-09-10    Starboard Value Acquisition    SVACU
# 202 2020-09-11         Broadstone Acquisition    BSN.U
# 203 2020-09-11                    Ribbit LEAP   LEAP.U
# 204 2020-09-11  Tortoise Acquisition Corp. II   SNPR.U
# 205 2020-09-11           TWC Tech Holdings II    TWCTU
#
#                                               Managers  Price  Price.1  \
# 1                                      Jefferies/ CICC   14.0    14.75
# 2                             Credit Suisse/ Citigroup   11.0    11.03
# 3                Citigroup/ Credit Suisse/ J.P. Morgan   13.5    13.50
# ...

# %%
# ipo.info()
ipo.groupby(ipo['Date'].dt.day)['% Px Chng '].mean().plot(kind='bar',figsize=(6,5),color='b',title="1st Day Mean IPO Percentage Change")
# Out:
# <Axes: title={'center': '1st Day Mean IPO Percentage Change'}, xlabel='Date'>

# %%
ipo.groupby(ipo['Date'].dt.day)['% Px Chng '].median().plot(kind='bar',figsize=(6,5),color='b',title="1st Day Median IPO Percentage Change")
# Out:
# <Axes: title={'center': '1st Day Median IPO Percentage Change'}, xlabel='Date'>

# %%
ipo["% Px Chng "].describe()
# Out:
# count    205.000000
# mean       0.205957
# std        0.417217
# min       -0.228000
# 25%        0.000000
# 50%        0.020000
# 75%        0.261667
# max        2.493750
# Name: % Px Chng , dtype: float64

# %%
ipo["% Px Chng "].hist(figsize=(6,4),bins=200,color='red')
# Out:
# <Axes: >

# %%
ipos = ipo
ipos.columns
# Out:
# Index(['Date', 'Issuer', 'Symbol', ' Managers', 'Price', 'Price.1', 'Close',
#        '% Px Chng ', 'Opening', 'Close.1', 'Ratings', 'Performed'],
#       dtype='object')
